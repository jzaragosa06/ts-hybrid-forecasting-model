# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.width', 55)
import seaborn as sns
import matplotlib.pyplot as plt
df_raw = pd.read_csv(r"/workspaces/ts-hybrid-forecasting-model/multivariate/evaluations/ridge_lasso_enr_dt/mae.csv")
data = pd.read_csv(r"/workspaces/ts-hybrid-forecasting-model/multivariate/evaluations/ridge_lasso_enr_dt/mae.csv", index_col=0)
df_dataset_removed = pd.read_csv("/workspaces/ts-hybrid-forecasting-model/multivariate/evaluations/ridge_lasso_enr_dt/mae.csv").drop(columns="fname", axis = 1)

# %% [markdown]
# We scaled the data using min max scaling to enable comparison and to prevent scale of each dataset affect the interpretation.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_dataset_removed = pd.DataFrame(scaler.fit_transform(df_dataset_removed), columns=df_dataset_removed.columns)
data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# The csv file consist of the performance of machine learning models against sampled univariate time series data from M4 competition (i.e., from each domain, we sampled 50 datasets). MAE was used as an evaluation metrics (performance metrics).

# %% [markdown]
# Basic summary

# %%
df_dataset_removed.describe()
# Out:
#             ridge       lasso         enr  \
# count  250.000000  250.000000  250.000000
# mean     0.170188    0.169585    0.170239
# std      0.164790    0.163759    0.164082
# min      0.000000    0.000000    0.000000
# 25%      0.040687    0.042038    0.041535
# 50%      0.107049    0.109717    0.110719
# 75%      0.277459    0.268524    0.272597
# max      1.000000    1.000000    1.000000
#
#                dt  ridge_lasso_enr_dt
# count  250.000000          250.000000
# mean     0.040777            0.169486
# std      0.085006            0.163517
# min      0.000000            0.000000
# 25%      0.007937            0.040366
# 50%      0.016563            0.106337
# 75%      0.039586            0.268087
# max      1.000000            1.000000

# %% [markdown]
# Side-by-side box plot

# %%
plt.figure(figsize=(10, 6))
plt.xlabel("Models")  # Replace with your x-axis label
plt.ylabel("MAE")  # Replace with your y-axis label
sns.boxplot(data=df_dataset_removed, palette="Blues")
# Show the plot
# plt.title("Side-by-Side Boxplot of Numerical Columns")
plt.show()

# %%
from scipy.stats import ttest_ind, ttest_rel

# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and ARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["ridge"].values

t_stat, p_value = ttest_rel(group1, group2, alternative="less")
print("one-tailed test - ridge_lasso_enr_dt and ridge: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")

# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["lasso"].values

t_stat, p_value = ttest_rel(group1, group2, alternative="less")
print("one-tailed test - ridge_lasso_enr_dt and lasso: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")


# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["enr"].values

t_stat, p_value = ttest_rel(group1, group2, alternative="less")
print("one-tailed test - ridge_lasso_enr_dt and enr: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")


# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["dt"].values

t_stat, p_value = ttest_rel(group1, group2, alternative="less")
print("one-tailed test - ridge_lasso_enr_dt and dt: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")
# Out:
# one-tailed test - ridge_lasso_enr_dt and ridge:
# T-statistic: -1.0234380602943935, P-value: 0.1535
# one-tailed test - ridge_lasso_enr_dt and lasso:
# T-statistic: -0.17930594687129417, P-value: 0.4289
# one-tailed test - ridge_lasso_enr_dt and enr:
# T-statistic: -1.2831269698191308, P-value: 0.1003
# one-tailed test - ridge_lasso_enr_dt and dt:
# T-statistic: 11.927125110762674, P-value: 1.0000

# %%
from scipy.stats import ttest_ind, ttest_rel

# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and ARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["ridge"].values

t_stat, p_value = ttest_ind(group1, group2, alternative="less", equal_var=False)
print("one-tailed test - ridge_lasso_enr_dt and ridge: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")

# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["lasso"].values

t_stat, p_value = ttest_ind(group1, group2, alternative="less", equal_var=False)
print("one-tailed test - ridge_lasso_enr_dt and lasso: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")


# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["enr"].values

t_stat, p_value = ttest_ind(group1, group2, alternative="less", equal_var=False)
print("one-tailed test - ridge_lasso_enr_dt and enr: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")


# alternative hyphothesis: group1 > group2
# ridge_lasso_enr_dt  and SARIMA
# group1
group1 = df_dataset_removed["ridge_lasso_enr_dt"].values
# group2
group2 = df_dataset_removed["dt"].values

t_stat, p_value = ttest_ind(group1, group2, alternative="less", equal_var=False)
print("one-tailed test - ridge_lasso_enr_dt and dt: ")
print(f"T-statistic: {t_stat}, P-value: {p_value:.4f}")
# Out:
# one-tailed test - ridge_lasso_enr_dt and ridge:
# T-statistic: -0.04777588509228871, P-value: 0.4810
# one-tailed test - ridge_lasso_enr_dt and lasso:
# T-statistic: -0.006735177290477337, P-value: 0.4973
# one-tailed test - ridge_lasso_enr_dt and enr:
# T-statistic: -0.051377124069102525, P-value: 0.4795
# one-tailed test - ridge_lasso_enr_dt and dt:
# T-statistic: 11.042603443081756, P-value: 1.0000

# %% [markdown]
# Side-by-side box plot where outliers are removed using IQR method.

# %%
# Function to detect and remove outliers using the IQR method
def remove_outliers_iqr(df):
    df = df.copy(deep=True)
    for col in df.select_dtypes(
        include="number"
    ).columns:  # Loop through each numerical column
        Q1 = df[col].quantile(0.25)  # First quartile (25th percentile)
        Q3 = df[col].quantile(0.75)  # Third quartile (75th percentile)
        IQR = Q3 - Q1  # Interquartile range

        # Define the outlier boundaries
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Remove rows where the value in this column is an outlier
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

    return df


# Assuming df is your original DataFrame
df_clean = remove_outliers_iqr(df_dataset_removed)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_clean, palette="Blues")
plt.xlabel("Models")  # Replace with your x-axis label
plt.ylabel("MAE")  # Replace with your y-axis label

# Show the plot
# plt.title("Side-by-Side Boxplot of Numerical Columns")
plt.show()

# %% [markdown]
# average rank of model's performance

# %%
# Rank each model's performance (lower MAE = better performance, so rank ascending)
ranked_data = data.rank(axis=1, method='average', ascending=True)
# Calculate the average rank for each model across all datasets
average_ranks = ranked_data.mean(axis=0).sort_values()
# print("Average Ranks for Each Model:\n", average_ranks)
average_ranks
# Out:
# dt                    1.720
# ridge_lasso_enr_dt    3.226
# lasso                 3.232
# enr                   3.362
# ridge                 3.460
# dtype: float64

# %% [markdown]
# Bar graph of average rank of model's performance

# %%
blue_palette = sns.color_palette("Blues", n_colors=len(average_ranks))

# Plot the bar chart with the blue color palette
average_ranks.plot(kind='bar', figsize=(10, 6), color=blue_palette)

# Add labels and title if needed
plt.ylabel('Average Rank')
plt.xlabel('Models')
plt.xticks(rotation=45)
# plt.title('Average Rank of Models Across Datasets')
plt.show()

# %% [markdown]
# Heat map of model ranking per dataset

# %%
# # Plot heatmap of ranked models
# plt.figure(figsize=(10, 15))
# sns.heatmap(ranked_data, annot=False, cmap='coolwarm', linewidths=0.5)
# plt.title('Model Rankings per Dataset')
# plt.xlabel('Models')
# plt.ylabel('Datasets')
# plt.show()
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Plot heatmap of ranked models with a color bar label
# plt.figure(figsize=(10, 15))
# sns.heatmap(ranked_data, annot=False, cmap='coolwarm', linewidths=0.5, 
#             cbar_kws={'label': 'Ranking Score'})  # Add label for the color bar

# # Add labels for the plot
# plt.title('Model Rankings per Dataset')
# plt.xlabel('Models')
# plt.ylabel('Datasets')

# plt.show()

# import matplotlib.pyplot as plt
# import seaborn as sns

# # Plot heatmap of ranked models with a detailed color bar label
# plt.figure(figsize=(10, 15))
# sns.heatmap(ranked_data, annot=False, cmap='coolwarm', linewidths=0.5, 
#             cbar_kws={'label': 'Ranking Score\n1 = Best, 9 = Worst'})  # Descriptive label

# # Add labels for the plot
# plt.title('Model Rankings per Dataset')
# plt.xlabel('Models')
# plt.ylabel('Datasets')

# plt.show()

import matplotlib.pyplot as plt
import seaborn as sns

# Plot heatmap of ranked models with a smaller color bar
plt.figure(figsize=(13, 15))
sns.heatmap(
    ranked_data,
    annot=False,
    cmap='coolwarm',
    linewidths=0.5,
    cbar_kws={'label': 'Ranking Score\n1 = Best, 9 = Worst', 'shrink': 0.3}  # Adjust shrink value
)

# Add labels for the plot
# plt.title('Model Rankings per Dataset')
plt.xlabel('Models')
plt.ylabel('Datasets')

plt.show()
